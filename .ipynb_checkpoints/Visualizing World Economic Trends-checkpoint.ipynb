# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import csv
import os

country_profiles_file = "country_profile_variables.csv"

# %%
# loading csv file and putting into dataframe

country_data = pd.read_csv(country_profiles_file)
country_data.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
# Cleaning up the data!

environ_df = country_data.loc[:,["country", 
                                 "Region",
                                 "GDP: Gross domestic product (million current US$)", 
                                 "GDP per capita (current US$)",'CO2 emission estimates (million tons/tons per capita)']]

environ_df = environ_df.set_index("GDP: Gross domestic product (million current US$)")
environ_df = environ_df.drop('-99', axis = 0)

environ_df = environ_df.reset_index()
environ_df = environ_df.set_index("CO2 emission estimates (million tons/tons per capita)")
environ_df = environ_df.drop('-99', axis = 0)

environ_df = environ_df.rename(columns={"country":"Country"})
environ_df = environ_df.reset_index()
environ_df = environ_df.set_index("Country")

environ_df.rename(columns={"CO2 emission estimates (million tons/tons per capita)":"CO2 emission estimates (million tons)"}, inplace= True)


cleaned_environ_df = environ_df[["Region", "GDP: Gross domestic product (million current US$)", 
                         "GDP per capita (current US$)",
                         "CO2 emission estimates (million tons)"]]

# Grouping regions together to create cleaner graphs

cleaned_environ_df["Region"] = cleaned_environ_df["Region"].replace(["MiddleAfrica","EasternAfrica", 
                                                                     "WesternAfrica", "NorthernAfrica", 
                                                                     "SouthernAfrica"], "Africa")

cleaned_environ_df["Region"] = cleaned_environ_df["Region"].replace(["CentralAsia", "EasternAsia", 
                                                                     "South-easternAsia","WesternAsia", 
                                                                     "NorthernAsia", "SouthernAsia"], 
                                                                     "Asia")

cleaned_environ_df["Region"] = cleaned_environ_df["Region"].replace(["EasternEurope", "WesternEurope",
                                                                     "NorthernEurope", "SouthernEurope"], 
                                                                     "Europe")

cleaned_environ_df["Region"] = cleaned_environ_df["Region"].replace(["SouthAmerica","CentralAmerica"], 
                                                                     "SouthAmerica")


# cleaned_environ_df["Region"].value_counts()
cleaned_environ_df.head()
# print(cleaned_regions)
# Out:
#              Region  GDP: Gross domestic product (million current US$)  \
# Country
# Afghanistan    Asia                                              20270
# Albania      Europe                                              11541
# Algeria      Africa                                             164779
# Andorra      Europe                                               2812
# Angola       Africa                                             117955
#
#              GDP per capita (current US$)  \
# Country
# Afghanistan                         623.2
# Albania                            3984.2
# Algeria                            4154.1
# Andorra                           39896.4
# Angola                             4714.1
#
#              CO2 emission estimates (million tons)
# Country
# Afghanistan                                     63
# Albania                                         84
# Algeria                                       5900
# ...

# %%
# Grouping by region and running aggregate functions

grouped_env = cleaned_environ_df.groupby("Region")
grouped_gdp = grouped_env["GDP per capita (current US$)"].median()
grouped_co2 = round(grouped_env["CO2 emission estimates (million tons)"].sum(), 2)

gdp_co2_df = pd.DataFrame(grouped_gdp)
gdp_co2_df["CO2 emission estimates (million tons)"] = grouped_co2

# Changing names to increase readability
gdp_co2_df.rename({"NorthernAmerica":"North America",
                   "SouthAmerica":"South America",}, inplace = True)

gdp_co2_df = gdp_co2_df.reset_index()
gdp_co2_df.set_index("Region", inplace = True)

# removing outliers

gdp_co2_df.drop("Micronesia", axis=0, inplace = True)
gdp_co2_df.drop("Polynesia", axis=0, inplace = True)
gdp_co2_df.drop("Melanesia", axis=0, inplace = True)
gdp_co2_df.drop("Caribbean", axis=0, inplace = True)
gdp_co2_df.drop("Oceania", axis=0, inplace = True)
gdp_co2_df = gdp_co2_df.rename(columns={"GDP per capita (current US$)":"Median GDP per capita (current US$)"})

gdp_co2_df = gdp_co2_df.sort_values("Median GDP per capita (current US$)")

gdp_co2_df = gdp_co2_df.reset_index()




# co2_energy_df = pd.DataFrame(grouped_co2)
# print(grouped_gdp)
# print(grouped_species)
gdp_co2_df.head()


# co2_energy_df.head()
# Out:
#           Region  Median GDP per capita (current US$)  \
# 0         Africa                               1067.0
# 1           Asia                               4509.0
# 2  South America                               6137.1
# 3         Europe                              19239.2
# 4  North America                              49629.7
#
#    CO2 emission estimates (million tons)
# 0                                  45063
# 1                                 259017
# 2                                  40486
# 3                                 100308
# 4                                 103166

# %%
gdp_co2_bar = gdp_co2_df.plot(x= gdp_co2_df["Region"],
                              kind="bar", 
                              figsize = (10,5), 
                              title = "Median GDP Per Capita (USD) vs. Total CO2 Emission Estimate (Million Tons)",
                              rot = 0)
plt.rcParams['font.size'] = 13.0

plt.savefig("gdp_co2_bar.png")

# %%
gdp_list = list(gdp_co2_df["Median GDP per capita (current US$)"])
co2_list = list(gdp_co2_df["CO2 emission estimates (million tons)"])
zippedRatio_list = [round(a/b, 2) for a,b in zip(co2_list, gdp_list)]

region_list = list(gdp_co2_df["Region"])
ratio_df = pd.DataFrame(region_list)
ratio_df = ratio_df.rename(columns={0:"Region"})
ratio_df["CO2:GDP ratio"] = zippedRatio_list

colors = ["lightblue", "lightcoral", "lightgreen", "yellow", "orange"]
explode = (0,0.05,0,0,0)

plt.pie(zippedRatio_list, explode = explode, labels = region_list, colors= colors, shadow = True, startangle = 200, autopct='%1.1f%%')
plt.title("Identifying the Least Carbon Efficient Economies")
plt.axis("equal")

plt.savefig("ratio.png")
# ratio_df.head()

# %%
ratio_df.head()
# Out:
#           Region  CO2:GDP ratio
# 0         Africa          42.23
# 1           Asia          57.44
# 2  South America           6.60
# 3         Europe           5.21
# 4  North America           2.08
