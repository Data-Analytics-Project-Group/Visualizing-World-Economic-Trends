# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os

country_profiles_file = "country_profile_variables.csv"

# %%
country_data = pd.read_csv(country_profiles_file)
country_data.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
country_region_gdp_df = country_data.loc[:, ['country', 'Region','GDP: Gross domestic product (million current US$)']]

country_region_gdp_df
# Out:
#                                        country             Region  \
# 0                                  Afghanistan       SouthernAsia
# 1                                      Albania     SouthernEurope
# 2                                      Algeria     NorthernAfrica
# 3                               American Samoa          Polynesia
# 4                                      Andorra     SouthernEurope
# 5                                       Angola       MiddleAfrica
# 6                                     Anguilla          Caribbean
# 7                          Antigua and Barbuda          Caribbean
# 8                                    Argentina       SouthAmerica
# 9                                      Armenia        WesternAsia
# 10                                       Aruba          Caribbean
# 11                                   Australia            Oceania
# 12                                     Austria      WesternEurope
# ...

# %%
# for x in country_region_gdp_df['GDP: Gross domestic product (million current US$)']:
#     if x== -99
    
country_region_gdp_df.dtypes  
    
country_region_gdp_df[country_region_gdp_df['GDP: Gross domestic product (million current US$)'] != -99]

country_region_gdp_df['GDP: Gross domestic product (million current US$)'] = pd.to_numeric(country_region_gdp_df['GDP: Gross domestic product (million current US$)'], downcast='float')
country_region_gdp_df['GDP: Gross domestic product (million current US$)'].dtypes

country_region_gdp_df.groupby('Region').sum()
# Out:
#                    GDP: Gross domestic product (million current US$)
# Region
# Caribbean                                                   334306.0
# CentralAmerica                                             1370237.0
# CentralAsia                                                 302780.0
# EasternAfrica                                               306270.0
# EasternAsia                                               17302860.0
# EasternEurope                                              2575829.0
# Melanesia                                                    36455.0
# Micronesia                                                     909.0
# MiddleAfrica                                                231956.0
# NorthernAfrica                                              736158.0
# NorthernAmerica                                           19597288.0
# NorthernEurope                                             4664608.0
# ...

# %%
# country_data_groupby_region = country_data.groupby('Region').median()
# country_data_groupby_region
# country_data.dtypes



country_data['Population in thousands (2017)'] = pd.to_numeric(country_data['Population in thousands (2017)'], downcast='float')
country_data['Population in thousands (2017)'].dtypes

country_data['Population in thousands (2017)']

country_data_groupby_region_median = country_data.groupby('Region').median()
country_data_groupby_region_mean = country_data.groupby('Region').mean()
# population = country_data_groupby_region['Population in thousands (2017)']
country_data_groupby_region_median

gdp_region_median_df = country_data_groupby_region_median[['GDP: Gross domestic product (million current US$)']]
gdp_region_median_df.head()
# gdp_region_median_df = gdp_region_median_df.set_index('Region')
# gdp_region_median_df.head()
# # gdp_region_mean = country_data_groupby_region_mean['GDP: Gross domestic product (million current US$)']


# Use DataFrame.plot() in order to create a bar chart of the data
plot = gdp_region_median_df.plot(kind="bar", figsize=(20,15))

plot.set_xticklabels(country_data["Region"], rotation=45)

# Set a title for the chart
plt.title("GDP (million current US$) by Region")

plt.show()

# # Filter the DataFrame down only to those columns to chart
# state_and_inches = rain_df[["State","Inches"]]

# # Set the index to be "State" so they will be used as labels
# state_and_inches = state_and_inches.set_index("State")

# state_and_inches.head()









# plt.scatter(x=gdp, y=population, color="lightskyblue", 
#             edgecolors='black', marker='o', alpha=0.45, linewidth=0.6,label="Suburban")
